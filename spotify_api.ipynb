# %% [markdown]
# #### Importando librerias

# %%
import requests
import base64
import pandas as pd

# %% [markdown]
# #### Definiendo endpoints

# %%
url_base = 'https://api.spotify.com/v1'

# %%
endpoint_artist = '/artists/{artist_id}' # endpoint lugar donde se quiere ir
endpoint_artist_album = '/artists/{artist_id}/albums'
endpoint_album = '/albums/{album_id}'
endpoint_album_tracks = '/albums/{album_id}/tracks'

# %% [markdown]
# #### ID del Album

# %%
deluxe_id = '3T4tUhGYeRNVUGevb0wThu?highlight=spotify:track:7qiZfU4dY1lWllzX7mPBI3'

# %% [markdown]
# #### ID del artista Kygo en este caso

# %%
kygo_id = '23fqKkggKUBHNkbKtXEls4'
id_ed = '6eUKZXaKkcviH0Ku9w2n3V'

# %%
url_base + endpoint_artist.format(artist_id=kygo_id)
# Out:
# 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4'

# %% [markdown]
# #### Endpoint completo para hacer la solicitud a la API

# %%
response = requests.get(url_base + endpoint_artist.format(artist_id=kygo_id))

# %%
print(response)
print(response.status_code)
print(response.json())
# Out:
# <Response [401]>
# 401
# {'error': {'status': 401, 'message': 'No token provided'}}

# %%
token_url = 'https://accounts.spotify.com/api/token'

# %%
params = {'grant_type':'client_credentials'}

# %% [markdown]
# #### Creando solicitud con los parametros correctos (la identificación no esta completa por seguridad)

# %%
#datos de clientid y client secret de la pagina de la app de spotify (No son las credenciales exactas por seguridad)
client_id = 'b58cxxxx2d488xxxxxxfa85fb32'
client_secret = '9f1dsxxxx74xcf8200d57bxxxx9f0d'

#claves transformadas a base 64.

client_encoded = base64.b64encode(f'{client_id}:{client_secret}'.encode('utf-8'))
client_encoded = str(client_encoded)
client_encoded = client_encoded[2:-1]
print(client_encoded)

# %%
headers2 = {'Authorization':'basic YjUxxxxiMjc5NxxxxxxYzMwZmExxxxMzI6OWYxxxxxxxjM3NDdjZjgyMxxxxxFiYzlmMGQ='}
headers = {'Authorization':f'basic {client_encoded}'}

# %%
r = requests.post(token_url, data=params, headers=headers)

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# #### Obtener el token de acceso

# %%
r.json()

# %%
token = r.json()['access_token']

# %%
token

# %%
header = {'Authorization': 'Bearer {}'.format(token)}
header

# %%
url_base + endpoint_artist
# Out:
# 'https://api.spotify.com/v1/artists/{artist_id}'

# %% [markdown]
# #### Solicitud correcta

# %%
response = requests.get(url_base + endpoint_artist.format(artist_id=kygo_id), headers= header)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#  'followers': {'href': None, 'total': 8006429},
#  'genres': ['edm', 'pop', 'pop dance', 'tropical house'],
#  'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#  'id': '23fqKkggKUBHNkbKtXEls4',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb6567299e3c53cf2a250fbdce',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab676161000051746567299e3c53cf2a250fbdce',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f1786567299e3c53cf2a250fbdce',
#    'width': 160}],
#  'name': 'Kygo',
#  'popularity': 85,
#  'type': 'artist',
#  'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'}

# %% [markdown]
# #### Configurando busqueda por artista y parametros complementarios

# %%
url_busqueda = 'https://api.spotify.com/v1/search'

# %%
search_params = {'q':"kygo", 'type':"artist", 'market': "CL"}

# %%
busqueda = requests.get(url_busqueda, headers=header, params=search_params)

# %%
busqueda.status_code
# Out:
# 200

# %%
busqueda.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=kygo&type=artist&market=CL&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#     'followers': {'href': None, 'total': 8006429},
#     'genres': ['edm', 'pop', 'pop dance', 'tropical house'],
#     'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#     'id': '23fqKkggKUBHNkbKtXEls4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb6567299e3c53cf2a250fbdce',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051746567299e3c53cf2a250fbdce',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1786567299e3c53cf2a250fbdce',
#       'width': 160}],
#     'name': 'Kygo',
#     'popularity': 85,
#     'type': 'artist',
#     'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'},
# ...

# %%
busqueda.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=kygo&type=artist&market=CL&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#     'followers': {'href': None, 'total': 8006429},
#     'genres': ['edm', 'pop', 'pop dance', 'tropical house'],
#     'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#     'id': '23fqKkggKUBHNkbKtXEls4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb6567299e3c53cf2a250fbdce',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051746567299e3c53cf2a250fbdce',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1786567299e3c53cf2a250fbdce',
#       'width': 160}],
#     'name': 'Kygo',
#     'popularity': 85,
#     'type': 'artist',
#     'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'},
# ...

# %% [markdown]
# #### Pasando resultados desde un formato json a un data frame

# %%
df = pd.DataFrame(busqueda.json()['artists']['items'])
df.head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/2...
# 1  {'spotify': 'https://open.spotify.com/artist/6...
# 2  {'spotify': 'https://open.spotify.com/artist/0...
# 3  {'spotify': 'https://open.spotify.com/artist/5...
# 4  {'spotify': 'https://open.spotify.com/artist/5...
#
#                           followers                                 genres  \
# 0  {'href': None, 'total': 8006429}  [edm, pop, pop dance, tropical house]
# 1      {'href': None, 'total': 891}                                     []
# 2        {'href': None, 'total': 4}                                     []
# 3       {'href': None, 'total': 20}                                     []
# 4        {'href': None, 'total': 0}                                     []
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/23fqKkggKUB...  23fqKkggKUBHNkbKtXEls4
# ...

# %%
df.sort_values(by='popularity', ascending=False).iloc[0]['id']
# Out:
# '23fqKkggKUBHNkbKtXEls4'

# %% [markdown]
# #### Unificando funciones

# %%
def get_token(client_id, client_secret):
    encoded = base64.b64encode(bytes(client_id+':'+client_secret, 'utf-8'))
    params = {'grant_type':'client_credentials'}
    header = {'Authorization': 'Basic' +' '+ str(encoded,'utf-8')}
    r = requests.post('https://accounts.spotify.com/api/token', headers = header, data= params)
    if r.status_code !=200:
        print('Error en la request.', r.json())
        return None
    print('Token valido por {} segundos.'.format(r.json()['expires_in']))
    return r.json()['access_token']

# %%
token_func = get_token(client_id, client_secret)
# Out:
# Token valido por 3600 segundos.

# %%
header = {'Authorization': 'Bearer {}'.format(token_func)}

# %%
endpoint_album
# Out:
# '/artists/{artist_id}/albums'

# %%
url_base+endpoint_album
# Out:
# 'https://api.spotify.com/v1/artists/{artist_id}/albums'

# %% [markdown]
# #### Ir a albumes de un artista

# %%
params = {'country': 'CL'}

# %%
albums_kygo = requests.get(url_base+endpoint_album.format(artist_id=kygo_id), headers=header, params=params)

# %%
albums_kygo.status_code
# Out:
# 200

# %%
albums_kygo.json().keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
albums_kygo.json()['items']

# %% [markdown]
# #### Obtener albumes por artista

# %%
lista_albumes = [(album['id'], album['name']) for album in albums_kygo.json()['items']]
lista_albumes
# Out:
# [('7tcs1X9pzFvcLOPuhCstQJ', 'Golden Hour'),
#  ('7LbyVLGeEWZYOUKCecv3gI', 'Kids in Love (Remixes)'),
#  ('47oyrKaeobswT4T8zyaxdM', 'Kids in Love'),
#  ('0uMIzWh1uEpHEBell4rlF8', 'Cloud Nine'),
#  ('3R2mQavCvrDfM3kZL2B8dh', 'Freeze'),
#  ('2ox5UMCeda9P21urAcoXdt', 'Dancing Feet (feat. DNCE)'),
#  ('3SgXZqSc8UfHsbrseyYscm', 'Undeniable (feat. X Ambassadors)'),
#  ('0GzKBZSFdg6H5ZlYJ6RgCo', 'Love Me Now (feat. Zoe Wees)'),
#  ('4D5C19GMxQELgCLW1EnNeZ', 'Gone Are The Days (feat. James Gillespie)'),
#  ('6t95dMgjNYMtwXTKlISI42', 'Hot Stuff'),
#  ('1JFKchcdu3ewuhA5PIHWno', "What's Love Got to Do with It"),
#  ('3NLjETPKVCukXj19Ol7Grj', 'The Truth'),
#  ('3LhriqAiHJYw7rxvtlkvQc', 'Lose Somebody'),
#  ('34JUh6M6Bvy2Dvo13bWfu4', 'Freedom'),
#  ('5NtG3FTjuLNQPUhs60sebC', "I'll Wait"),
#  ('0lWWqdcdtFgSd1j06F9JZC', 'Like It Is'),
#  ('63VE57Ol6fcAC0fb6kGx5y', 'Forever Yours (Avicii Tribute)'),
#  ('6wCL4V0FajWaH933iLmCf1', 'Stargazing (Tariq Pijning Edit)'),
# ...

# %% [markdown]
# #### Enviar albumes a un data frame

# %%
df_albums_kygo = pd.DataFrame(albums_kygo.json()['items'])

# %%
df_albums_kygo.head(2)
# Out:
#   album_group album_type                                            artists  \
# 0       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 1       album      album  [{'external_urls': {'spotify': 'https://open.s...
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/7t...
# 1  {'spotify': 'https://open.spotify.com/album/7L...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/albums/7tcs1X9pzFvc...  7tcs1X9pzFvcLOPuhCstQJ
# 1  https://api.spotify.com/v1/albums/7LbyVLGeEWZY...  7LbyVLGeEWZYOUKCecv3gI
#
#                                               images                    name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...             Golden Hour
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Kids in Love (Remixes)
#
#   release_date release_date_precision  total_tracks   type  \
# ...

# %%
lista_albumes_df= df_albums_kygo[['id', 'name']]
lista_albumes_df.head()
# Out:
#                        id                    name
# 0  7tcs1X9pzFvcLOPuhCstQJ             Golden Hour
# 1  7LbyVLGeEWZYOUKCecv3gI  Kids in Love (Remixes)
# 2  47oyrKaeobswT4T8zyaxdM            Kids in Love
# 3  0uMIzWh1uEpHEBell4rlF8              Cloud Nine
# 4  3R2mQavCvrDfM3kZL2B8dh                  Freeze

# %%
ids = df_albums_kygo['id']
albumss = df_albums_kygo['name']
lista_fina = ids +', '+ albumss
lista_fina = list(lista_fina)
lista_fina[0]
# Out:
# '7tcs1X9pzFvcLOPuhCstQJ, Golden Hour'

# %% [markdown]
# #### Ir a tracks de albumes

# %%
url_base + endpoint_album_tracks.format(album_id='0uMIzWh1uEpHEBell4rlF8')
# Out:
# 'https://api.spotify.com/v1/albums/0uMIzWh1uEpHEBell4rlF8/tracks'

# %%
album_tracks = requests.get(url_base + endpoint_album_tracks.format(album_id='0uMIzWh1uEpHEBell4rlF8'), headers=header, params={'market':'CL'})
album_tracks.status_code
# Out:
# 200

# %% [markdown]
# #### Explorar el json anidado resultante de la solicitud de canciones del artista

# %%
album_tracks.json()
# Out:
# {'href': 'https://api.spotify.com/v1/albums/0uMIzWh1uEpHEBell4rlF8/tracks?offset=0&limit=20&market=CL',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#      'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#      'id': '23fqKkggKUBHNkbKtXEls4',
#      'name': 'Kygo',
#      'type': 'artist',
#      'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'}],
#    'disc_number': 1,
#    'duration_ms': 128546,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6bqHegYlJ2ihL0rw3uW65e'},
#    'href': 'https://api.spotify.com/v1/tracks/6bqHegYlJ2ihL0rw3uW65e',
#    'id': '6bqHegYlJ2ihL0rw3uW65e',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Intro',
#    'preview_url': 'https://p.scdn.co/mp3-preview/0c374bcf607452190387eaf5a23b6690432fa79d?cid=b58c0b27942d48899f4fec30fa85fb32',
#    'track_number': 1,
#    'type': 'track',
# ...

# %%
album_tracks.json().keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
album_tracks.json()['items']
# Out:
# [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#     'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#     'id': '23fqKkggKUBHNkbKtXEls4',
#     'name': 'Kygo',
#     'type': 'artist',
#     'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'}],
#   'disc_number': 1,
#   'duration_ms': 128546,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6bqHegYlJ2ihL0rw3uW65e'},
#   'href': 'https://api.spotify.com/v1/tracks/6bqHegYlJ2ihL0rw3uW65e',
#   'id': '6bqHegYlJ2ihL0rw3uW65e',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Intro',
#   'preview_url': 'https://p.scdn.co/mp3-preview/0c374bcf607452190387eaf5a23b6690432fa79d?cid=b58c0b27942d48899f4fec30fa85fb32',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:6bqHegYlJ2ihL0rw3uW65e'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
# ...

# %%
track_list= [(track['id'], track['name'])for track in album_tracks.json()['items']]
track_list
# Out:
# [('6bqHegYlJ2ihL0rw3uW65e', 'Intro'),
#  ('5masKPHeAOVNgxdLebIcK7', 'Stole the Show'),
#  ('3vRvuatWmKcHhxbv6choLR', 'Fiction (feat. Tom Odell)'),
#  ('2Vhd5uZB4brKHmM0MNxkZo', 'Raging (feat. Kodaline)'),
#  ('1I8tHoNBFTuoJAlh4hfVVE', 'Firestone'),
#  ('5SAckbSHhNJ41b3bn5XwPL', 'Happy Birthday (feat. John Legend)'),
#  ('12q7yTtyZfJjObmss6FQi3', "I'm in Love (feat. James Vincent McMorrow)"),
#  ('59JreAiZzOF6pB8nIqEi20', 'Oasis (feat. Foxes)'),
#  ('5nQojVsRxImTExfSXQ9qU2', 'Not Alone (feat. RHODES)'),
#  ('18YIDJGWXocUPFbAzTaq8g', 'Serious (feat. Matt Corby)'),
#  ('2FiSTH0GYpIioUgjfzMIja', 'Stay (feat. Maty Noyes)'),
#  ('2fZW7ByWe46rGih0FtP2XK', 'Nothing Left (feat. Will Heard)'),
#  ('6PyxrogMU9imKqVtKx6840', 'Fragile'),
#  ('3FZEv9JddkjHNFiMVxJYpS', 'Carry Me (feat. Julia Michaels)'),
#  ('6HsbMH5Bgkp4QgAp7MVZ8z', "For What It's Worth (feat. Angus & Julia Stone)")]

# %%
df_albums_tracks = pd.DataFrame(album_tracks.json()['items'])
df_albums_tracks.head()
# Out:
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit                                      external_urls  \
# 0       128546     False  {'spotify': 'https://open.spotify.com/track/6b...
# 1       223186     False  {'spotify': 'https://open.spotify.com/track/5m...
# 2       243946     False  {'spotify': 'https://open.spotify.com/track/3v...
# 3       224486     False  {'spotify': 'https://open.spotify.com/track/2V...
# 4       271640     False  {'spotify': 'https://open.spotify.com/track/1I...
#
#                                                 href                      id  \
# ...

# %% [markdown]
# #### Ir a albumes del artista de manera general

# %%
albums = requests.get(url_base + endpoint_album.format(album_id='0uMIzWh1uEpHEBell4rlF8'), headers=header, params={'market':'CL'})
albums.status_code
# Out:
# 200

# %%
albums.json()['tracks']['items']
# Out:
# [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#     'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#     'id': '23fqKkggKUBHNkbKtXEls4',
#     'name': 'Kygo',
#     'type': 'artist',
#     'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'}],
#   'disc_number': 1,
#   'duration_ms': 128546,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6bqHegYlJ2ihL0rw3uW65e'},
#   'href': 'https://api.spotify.com/v1/tracks/6bqHegYlJ2ihL0rw3uW65e',
#   'id': '6bqHegYlJ2ihL0rw3uW65e',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Intro',
#   'preview_url': 'https://p.scdn.co/mp3-preview/0c374bcf607452190387eaf5a23b6690432fa79d?cid=b58c0b27942d48899f4fec30fa85fb32',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:6bqHegYlJ2ihL0rw3uW65e'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
# ...

# %% [markdown]
# #### Convertir json en data frame para manipular mejor la información

# %%
df_albums = pd.DataFrame(albums.json()['tracks']['items'])
df_albums.head()
# Out:
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit                                      external_urls  \
# 0       128546     False  {'spotify': 'https://open.spotify.com/track/6b...
# 1       223186     False  {'spotify': 'https://open.spotify.com/track/5m...
# 2       243946     False  {'spotify': 'https://open.spotify.com/track/3v...
# 3       224486     False  {'spotify': 'https://open.spotify.com/track/2V...
# 4       271640     False  {'spotify': 'https://open.spotify.com/track/1I...
#
#                                                 href                      id  \
# ...

# %% [markdown]
# ### Funcion obtener información completa

# %%
def obtener_discografia(artist_id, token, return_name = False, page_limit = 50, country= None):
    url = url_base + endpoint_artist_album
    header = {'Authorization': f'Bearer {token}'}
    params = {'limit': page_limit,
              'offset': 0,
              'country': country}
    lista = []
    r = requests.get(url, params=params, headers=header)

    if r.status_code != 200:
        print('Error en la request.', r.json())
        return None

    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]

    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header)
        if r.status_code != 200:
            print('Error en la request.', r.json())
            return None

        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista += [item['id'] for item in r.json()['items']]
    
    return lista

# %% [markdown]
# #### Obtener todas las canciones del artista

# %%
def obtener_tracks(artist_id, token, return_name = False, page_limit = 50, country= None):
    url = url_base + endpoint_album_tracks
    header = {'Authorization': f'Bearer {token}'}
    params = {'limit': page_limit,
              'offset': 0,
              'country': country}
    lista = []
    r = requests.get(url, params=params, headers=header)

    if r.status_code != 200:
        print('Error en la request.', r.json())
        return None

    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]

    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header)
        if r.status_code != 200:
            print('Error en la request.', r.json())
            return None

        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista += [item['id'] for item in r.json()['items']]
    
    return lista

# %%
for album in obtener_discografia(kygo_id, token, return_name=True, country='CL'):
    print(album[1])
    for track in obtener_tracks(album[0], token, return_name=True, market='CL'):
        print('\t', track[1])
